# %% [markdown]
# # Distance of comments from planning applications
#
# This notebook calculates the distance from each of the comments to the corresponding planning application it was left on

# %%
import numpy as np
import regex

from transformers import BertTokenizerFast, pipeline

from database.comments import Comments

import sys
sys.path.append('../pipeline')
from nlp_tasks import NLP_Tasks
